# %%
import prophet
print(prophet.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20732\1393914851.py in <module>
# ----> 1 import prophet
#       2 print(prophet.__version__)
#
# ModuleNotFoundError: No module named 'prophet'

# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.3.0-py3-none-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.4 in c:\users\hp\anaconda3\lib\site-packages (from prophet) (1.4.4)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
#      ---------------------------------------- 99.1/99.1 kB 5.6 MB/s eta 0:00:00
# Collecting importlib_resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\hp\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Collecting holidays<1,>=0.25
#   Downloading holidays-0.83-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in c:\users\hp\anaconda3\lib\site-packages (from prophet) (1.21.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from prophet) (3.5.2)
# Collecting stanio<2.0.0,>=0.4.0
#   Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: python-dateutil in c:\users\hp\anaconda3\lib\site-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from importlib_resources->prophet) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Installing collected packages: stanio, importlib_resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.3.0 holidays-0.83 importlib_resources-6.5.2 prophet-1.3.0 stanio-0.5.1

# %%
from prophet import Prophet
print("Prophet installed successfully")
# Out:
# Prophet installed successfully

# %%
pip show prophet
# Out:
# Name: prophet
# Version: 1.3.0
# Summary: Automatic Forecasting Procedure
# Home-page:
# Author:
# Author-email: "Sean J. Taylor" <sjtz@pm.me>, Ben Letham <bletham@fb.com>
# License: MIT
# Location: c:\users\hp\anaconda3\lib\site-packages
# Requires: cmdstanpy, holidays, importlib_resources, matplotlib, numpy, pandas, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet

# %%
monthly_sales = monthly_sales.rename(columns={
    'Order Date': 'ds',
    'Revenue': 'y'
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42884\1914460116.py in <module>
# ----> 1 monthly_sales = monthly_sales.rename(columns={
#       2     'Order Date': 'ds',
#       3     'Revenue': 'y'
#       4 })
#
# NameError: name 'monthly_sales' is not defined
